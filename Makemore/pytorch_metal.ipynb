# %% [markdown]
# My ML Environments:
#
# 1. Pytorch standard: mlenv/
# 2. Jax
# 3. Jax - Metal
# 4. ANE
#
# Path: /Volumes/code/envs/ + Env Folder name + /bin/python

# %%
# from datasets import load_dataset
import torch

# %%
# # Save the names to a file
# def saveNames():
#     ds = load_dataset("baby_names", data_files={'train': 'train/data-00000-of-00001.arrow', 'test': 'test/data-00000-of-00001.arrow'})
#     trainDS = ds["train"]
#     testDS = ds["test"]
#     names = trainDS["Names"] + testDS["Names"]
#     len(names)

#     # Save the names to a file
#     with open("namesLower.txt", "w") as f:
#         for name in names:
#             f.write(name.lower() + "\n")

# saveNames()

# %%
words = open('names.txt').read().splitlines()
len(words)
# Out:
# 1356048

# %%
device  = "cpu"
if (device == "mps"):
  mps_device = torch.device("mps")
  N = torch.zeros(28, 28, dtype=torch.int32, device=mps_device)
elif (device == "cpu"):
  N = torch.zeros((27, 27), dtype=torch.int32, device="cpu")
elif (device == "acc"):
  accelerator = Accelerator()
  device = accelerator.device
  N = torch.zeros((27, 27), dtype=torch.int32).to(device)
elif (device == "coreml"):
  import coremltools as ct
  class SimpleModel(torch.nn.Module):
    def __init__(self, a,b):
      super(SimpleModel, self).__init__()
      self.fc = torch.nn.Linear(a,b)
      # Make the weights 0

    def addWeight(self, x, y):
      self.fc.weight.data[x][y] += 1

    def forward(self, x):
      return self.fc(x)
    
  model = SimpleModel(27, 27)
  # N = torch.zeros((27, 27), dtype=torch.int32, device="coreml")

# %% [markdown]
# ### Bigram Language Model
#
# Simple and Weak language model

# %%
chars = sorted(list(set(''.join(words))))
stoi = {s:i+1 for i,s in enumerate(chars)}
stoi['.'] = 0
itos = {i:s for s,i in stoi.items()}

# %%
# make 27*27 matrix
matrix = [[0]*27 for i in range(27)]

for w in words:
    chs = ['.'] + list(w) + ['.']
    for ch1, ch2 in zip(chs, chs[1:]):
        ix1 = stoi[ch1]
        ix2 = stoi[ch2]
        # matrix[ix1][ix2] += 1
        N[ix1, ix2] +=1
     
     
# Update the tensor
for i in range(27):
    for j in range(27):
        N[i][j] = matrix[i][j]

# 50+
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 10
#       8         ix2 = stoi[ch2]
#       9         # matrix[ix1][ix2] += 1
# ---> 10         N[ix1, ix2] +=1
#      13 # Update the tensor
#      14 for i in range(27):
#
# KeyboardInterrupt:

# %%
# !uv pip install matplotlib

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(27,27))
plt.imshow(N, cmap='Blues')
for i in range(27):
    for j in range(27):
        chstr = itos[i] + itos[j]
        plt.text(j,i,chstr,ha="center", va="bottom", color='gray')
        repeatTimes = round(N[i,j].item()/1000, 3)
        plt.text(j,i,repeatTimes, ha="center", va="top", color='gray')
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(26.5), np.float64(26.5), np.float64(-0.5))

# %%
rowSum = N.sum(axis=1, keepdims=True).float()
N = N.float() + 1
N /= rowSum
N
# Out:
# tensor([[7.3744e-07, 1.1041e-01, 3.7701e-02, 6.3009e-02, 6.7641e-02, 3.6936e-02,
#          1.2716e-02, 2.1807e-02, 2.1069e-02, 1.5005e-02, 8.6161e-02, 8.5428e-02,
#          5.5858e-02, 7.9071e-02, 3.4316e-02, 9.8064e-03, 1.4822e-02, 4.1776e-03,
#          4.8941e-02, 7.8660e-02, 6.1991e-02, 2.1467e-03, 1.1453e-02, 8.2453e-03,
#          2.3473e-03, 1.3683e-02, 1.6620e-02],
#         [2.4771e-01, 8.4063e-03, 1.3662e-02, 1.5385e-02, 2.7154e-02, 1.7676e-02,
#          3.0653e-03, 4.8611e-03, 4.7061e-02, 3.7926e-02, 5.3667e-03, 1.7613e-02,
#          1.5778e-02, 6.2903e-04, 7.6423e-03, 1.0484e-01, 3.7936e-04, 6.4848e-06,
#          7.5649e-02, 3.9428e-03, 6.8434e-02, 1.0859e-02, 5.6742e-04, 3.6250e-03,
#          1.7509e-04, 5.4226e-02, 1.1543e-02],
#         [3.6065e-02, 9.2707e-02, 2.4132e-02, 2.6435e-02, 3.9836e-02, 8.0637e-02,
#          4.7933e-03, 1.7842e-02, 9.7018e-03, 6.0133e-02, 4.6350e-03, 1.8029e-02,
#          8.4258e-02, 3.2934e-02, 1.0886e-01, 6.1392e-03, 6.9309e-03, 1.6194e-03,
#          1.1904e-01, 1.6303e-01, 1.9526e-02, 9.5003e-04, 7.4707e-03, 1.2566e-02,
#          3.7929e-03, 5.8369e-03, 1.2293e-02],
#         [2.3313e-02, 2.4480e-01, 2.0708e-04, 1.0899e-05, 8.5011e-04, 2.2489e-01,
#          1.0899e-05, 1.6348e-04, 3.2696e-04, 3.4101e-01, 3.2696e-04, 1.6784e-03,
#          4.9590e-03, 1.0899e-05, 2.5176e-03, 1.0153e-01, 1.5258e-04, 1.0899e-05,
#          1.5564e-02, 2.2888e-04, 4.3595e-05, 2.0926e-03, 1.5149e-03, 1.0899e-05,
#          1.0899e-05, 3.4048e-02, 1.0899e-05],
#         [5.0808e-02, 2.9679e-01, 3.8983e-04, 1.0396e-04, 4.3142e-03, 1.3241e-01,
#          2.0011e-03, 2.0791e-04, 1.9388e-02, 1.5799e-01, 1.4034e-03, 3.3526e-03,
#          6.5232e-03, 2.9887e-03, 1.6100e-01, 5.0470e-02, 2.5989e-05, 2.5989e-05,
#          1.5853e-02, 1.3488e-02, 5.4837e-03, 1.8114e-02, 5.1978e-05, 5.9774e-04,
#          2.5989e-05, 5.6396e-02, 4.9379e-04],
#         [1.9024e-01, 2.1032e-01, 3.3841e-04, 9.2499e-03, 3.4405e-03, 5.3694e-02,
#          5.6966e-03, 5.6402e-05, 1.1844e-03, 1.9447e-01, 5.0761e-04, 5.6402e-05,
#          2.0925e-02, 3.3277e-03, 1.0152e-03, 4.5008e-02, 1.1280e-04, 5.6402e-05,
#          5.6402e-05, 3.9312e-02, 7.6763e-02, 1.9853e-02, 1.1280e-04, 7.7834e-03,
#          4.3598e-02, 3.9820e-02, 3.4518e-02],
#         [2.5948e-01, 1.8765e-01, 2.7213e-03, 1.4001e-02, 2.4191e-02, 3.6868e-02,
#          1.0552e-03, 2.7125e-03, 2.4816e-03, 1.6752e-02, 3.7619e-03, 9.9528e-03,
#          9.8710e-02, 1.6076e-02, 1.6970e-01, 2.8222e-02, 1.1341e-03, 1.7158e-03,
#          3.1633e-02, 4.9761e-02, 1.1493e-02, 1.1680e-02, 8.9824e-03, 1.4527e-03,
#          1.5433e-03, 2.2829e-03, 4.0688e-03],
#         [9.3343e-02, 3.4754e-01, 3.4420e-03, 1.6258e-03, 6.2981e-04, 1.5884e-01,
#          2.9293e-05, 9.9597e-04, 1.2596e-02, 1.5095e-01, 1.0692e-03, 1.6697e-03,
#          3.0406e-02, 2.4079e-02, 1.6990e-03, 4.3720e-02, 6.0051e-04, 2.9293e-05,
#          1.0751e-02, 2.2263e-03, 2.7389e-03, 2.6027e-02, 1.9041e-03, 8.7880e-04,
#          5.8587e-05, 5.4691e-02, 2.7858e-02]])

# %%
# copy tensor N to matrix
for i in range(27):
    for j in range(27):
        matrix[i][j] = N[i][j].item()

# %%
# python math module
import math

# %%
log_likelihood = 0.0
n = 0
for w in words:
    chs = ['.'] + list(w) + ['.']
    for ch1, ch2 in zip(chs, chs[1:]):
        ix1 = stoi[ch1]
        ix2 = stoi[ch2]
        prob = matrix[ix1][ix2]
        logprob = math.log(prob)
        log_likelihood += logprob
        n += 1
        # print(f'{ch1}->{ch2} : {logprob:.1f}')
print(f'log likelihood: {log_likelihood:.1f}')
print(f'negative log likelihood: {-log_likelihood:.1f}')
print(f'avergae negative log likelihood: {-log_likelihood/n:.1f}') # Lower the better
# Out:
# log likelihood: -23684384.0
# negative log likelihood: 23684384.0
# avergae negative log likelihood: 2.4

# %%
seed = 2147483647

for i in range(10):
  ix = 0
  while True:
    gen = torch.manual_seed(seed)
    ix = torch.multinomial(N[ix], 1, replacement=True, generator=gen).item()
    print(itos[ix], end='')
    if ix == 0:
      break
  print()
# Out:
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[118], line 6
#       4 ix = 0
#       5 while True:
# ----> 6   gen = torch.manual_seed(seed)
#       7   ix = torch.multinomial(N[ix], 1, replacement=True, generator=gen).item()
#       8   print(itos[ix], end='')
#
# File /Volumes/code/envs/mlenv/lib/python3.11/site-packages/torch/_dynamo/eval_frame.py:451, in _TorchDynamoContext.__call__.<locals>._fn(*args, **kwargs)
#     449 prior = set_eval_frame(callback)
#     450 try:
# --> 451     return fn(*args, **kwargs)
#     452 finally:
#     453     set_eval_frame(prior)
#
# File /Volumes/code/envs/mlenv/lib/python3.11/site-packages/torch/_dynamo/external_utils.py:36, in wrap_inline.<locals>.inner(*args, **kwargs)
#      34 @functools.wraps(fn)
#      35 def inner(*args, **kwargs):
# ---> 36     return fn(*args, **kwargs)
#
# File /Volumes/code/envs/mlenv/lib/python3.11/site-packages/torch/random.py:45, in manual_seed(seed)
#      42 import torch.cuda
#      44 if not torch.cuda._is_in_bad_fork():
# ---> 45     torch.cuda.manual_seed_all(seed)
#      47 import torch.mps
#      48 if not torch.mps._is_in_bad_fork():
#
# File /Volumes/code/envs/mlenv/lib/python3.11/site-packages/torch/cuda/random.py:126, in manual_seed_all(seed)
#     123         default_generator = torch.cuda.default_generators[i]
#     124         default_generator.manual_seed(seed)
# --> 126 _lazy_call(cb, seed_all=True)
#
# File /Volumes/code/envs/mlenv/lib/python3.11/site-packages/torch/cuda/__init__.py:230, in _lazy_call(callable, **kwargs)
#     228 global _lazy_seed_tracker
#     229 if kwargs.get("seed_all", False):
# --> 230     _lazy_seed_tracker.queue_seed_all(callable, traceback.format_stack())
#     231 elif kwargs.get("seed", False):
#     232     _lazy_seed_tracker.queue_seed(callable, traceback.format_stack())
#
# File /opt/homebrew/Cellar/python@3.11/3.11.9/Frameworks/Python.framework/Versions/3.11/lib/python3.11/traceback.py:214, in format_stack(f, limit)
#     212 if f is None:
#     213     f = sys._getframe().f_back
# --> 214 return format_list(extract_stack(f, limit=limit))
#
# File /opt/homebrew/Cellar/python@3.11/3.11.9/Frameworks/Python.framework/Versions/3.11/lib/python3.11/traceback.py:41, in format_list(extracted_list)
#      29 def format_list(extracted_list):
#      30     """Format a list of tuples or FrameSummary objects for printing.
#      31
#      32     Given a list of tuples or FrameSummary objects as returned by
#    (...)
#      39     whose source text line is not None.
#      40     """
# ---> 41     return StackSummary.from_list(extracted_list).format()
#
# File /opt/homebrew/Cellar/python@3.11/3.11.9/Frameworks/Python.framework/Versions/3.11/lib/python3.11/traceback.py:538, in StackSummary.format(self)
#     536 count = 0
#     537 for frame_summary in self:
# --> 538     formatted_frame = self.format_frame_summary(frame_summary)
#     539     if formatted_frame is None:
#     540         continue
#
# File /opt/homebrew/Cellar/python@3.11/3.11.9/Frameworks/Python.framework/Versions/3.11/lib/python3.11/traceback.py:470, in StackSummary.format_frame_summary(self, frame_summary)
#     468 line = frame_summary._original_line
#     469 orig_line_len = len(line)
# --> 470 frame_line_len = len(frame_summary.line.lstrip())
#     471 stripped_characters = orig_line_len - frame_line_len
#     472 if (
#     473     frame_summary.colno is not None
#     474     and frame_summary.end_colno is not None
#     475 ):
#
# KeyboardInterrupt:
